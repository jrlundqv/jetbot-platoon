# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt
import os 
from datetime import datetime  # For timestamps
import time  # Additional import that might be useful for delays
import numpy as np
from jetbot import Robot, Camera



class LineDetector:
    def __init__(self, camera, width=224, height=224, save_dir='images_collection' ):
        self.camera = camera
        #self.camera = Camera.instance(width=width, height=height)
        self.image_height = height
        self.image_width = width
        
        self.save_dir = save_dir
        
        # Create directory for saving images if it doesn't exist
        if not os.path.exists(save_dir):
            os.makedirs(save_dir)
            os.makedirs(os.path.join(save_dir, 'original'))
            os.makedirs(os.path.join(save_dir, 'processed'))
            
    def preprocess_image(self, image):
        # Convert to grayscale
        gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)

        # Apply Gaussian blur to reduce noise
        blurred = cv2.GaussianBlur(gray, (5, 5), 0)

        # Apply threshold to get binary image
        _, binary = cv2.threshold(blurred, 111, 255, cv2.THRESH_BINARY_INV)

        
        roi_height = self.image_height // 2
        roi = binary[roi_height:, :]

        # Find connected components
        num_labels, labels, stats, centroids = cv2.connectedComponentsWithStats(roi, connectivity=8)

        # Get areas of all components (excluding background)
        areas = stats[1:, cv2.CC_STAT_AREA]  # Skip background (label 0)
        road = "small"
        if len(areas) > 0:
            # Calculate mean and median of component areas
            mean_area = np.mean(areas)
            median_area = np.median(areas)
            # Dynamically set minimum area threshold
            # If there are large components (like in the narrow road case),
            # set a higher threshold relative to the mean area
            if mean_area > 70:  # Adjust this threshold based on your cases
                print(f"small raod: {mean_area}")
                road = "small"
                min_area = mean_area * 0.6  # Remove components smaller than 10% of mean
                filtered_binary = np.zeros_like(roi)
                # Apply the adaptive threshold
                for label in range(1, num_labels):
                    area = stats[label, cv2.CC_STAT_AREA]
                    if area >= min_area:
                        #print(f"added part with area: {area} ")
                        filtered_binary[labels == label] = 255

                # Optional: Clean up the remaining components
                kernel = np.ones((3,3), np.uint8)
                filtered_binary = cv2.morphologyEx(filtered_binary, cv2.MORPH_CLOSE, kernel)
                filtered_binary = cv2.morphologyEx(filtered_binary, cv2.MORPH_OPEN, kernel)
            else:
                print(f"big raod: {mean_area}")
                road = "big"
                # For cases with smaller components (wider road),
                # use a more lenient threshold
                min_area = 5  # Minimum baseline threshold
                filtered_binary = roi  # If no components found, use original binary image           
        else:
            print("no components found")
            filtered_binary = roi  # If no components found, use original binary image

        return gray, blurred, filtered_binary, binary, road
        
        
    def detect_lines(self, binary_image):
        roi_height = 112
        roi = binary_image
        #roi = binary_image[roi_height:, :]

        edges = cv2.Canny(roi, 50, 150)

        lines = cv2.HoughLinesP(
            roi,
            rho=1,
            theta=np.pi/180,
            threshold=30,
            minLineLength=30,
            maxLineGap=80
        )

        left_lines = []
        right_lines = []

        if lines is not None:
            for line in lines:
                x1, y1, x2, y2 = line[0]
                if x2 - x1 == 0:
                    continue
                slope = (y2 - y1) / (x2 - x1)

                # Categorize lines as left or right based on slope and position
                line_center_x = (x1 + x2) / 2
                if slope < 0 and line_center_x < self.image_width/2:  # Left line
                    left_lines.append(line[0])
                elif slope > 0 and line_center_x > self.image_width/2:  # Right line
                    right_lines.append(line[0])

        return left_lines, right_lines, roi_height, roi
    
    def calculate_two_line_steering(self, left_lines, right_lines, roi_height):
        """
        Calculate steering angle based on position and angle between bottom lane points
        """
        image_center = self.image_width // 2

        # If no lines detected, go straight
        if not left_lines or not right_lines:
            return 0, image_center, image_center, 0, None

        # Find bottom points of each line
        def get_bottom_point(lines):
            max_y = -float('inf')
            bottom_point = None
            for line in lines:
                x1, y1, x2, y2 = line
                # Check both points of the line
                if y1 > max_y:
                    max_y = y1
                    bottom_point = (x1, y1)
                if y2 > max_y:
                    max_y = y2
                    bottom_point = (x2, y2)
            return bottom_point

        # Get bottom points
        left_bottom = get_bottom_point(left_lines)
        right_bottom = get_bottom_point(right_lines)

        if left_bottom is None or right_bottom is None:
            return 0, image_center, image_center, 0, None

        # Calculate position deviation
        left_x = left_bottom[0]
        right_x = right_bottom[0]
        center_x = (left_x + right_x) // 2
        deviation = center_x - image_center

        # Calculate angle between bottom points line and horizontal
        dx = right_bottom[0] - left_bottom[0]
        dy = right_bottom[1] - left_bottom[1]
        angle = np.arctan2(dy, dx) * 180 / np.pi

        # Combine position and angle for steering
        # Position component
        position_weight = 0.5
        angle_weight = 0.5

        max_angle = 30
        position_factor = deviation / (self.image_width / 2)  # Normalize to [-1, 1]
        angle_factor = angle / 45  # Normalize to [-1, 1], assuming max 45 degree deviation

        # Combine both factors
        steering_angle = -(position_weight * position_factor + angle_weight * angle_factor) * max_angle

        # Store bottom points for visualization
        bottom_points = {
            'left': (left_bottom[0], left_bottom[1] + roi_height),
            'right': (right_bottom[0], right_bottom[1] + roi_height),
            'angle': angle
        }

        return steering_angle, center_x, image_center, deviation, bottom_points

    def calculate_steering_angle(self, left_lines, right_lines, roi_height, road):
        """
        Calculate steering angle based on available lines
        """
        image_center = self.image_width // 2

        # Initialize previous_steering_angle if it doesn't exist
        if not hasattr(self, 'previous_steering_angle'):
            self.previous_steering_angle = 0

        # If no lines detected, maintain previous steering
        if not left_lines and not right_lines:
            return self.previous_steering_angle, image_center, image_center, 0, None

        # If both lines are detected, use the original two-line method
        if left_lines and right_lines:
            print("Mode 2 lines detected")
            # Get bottom points
            left_bottom = self.get_bottom_point(left_lines)
            right_bottom = self.get_bottom_point(right_lines)
            
            if left_bottom is None or right_bottom is None:
                
                return self.previous_steering_angle, image_center, image_center, 0, None
            
            # Calculate position deviation
            left_x = left_bottom[0]
            right_x = right_bottom[0]
            center_x = (left_x + right_x) // 2
            deviation = center_x - image_center
            
            # Calculate angle between bottom points
            dx = right_bottom[0] - left_bottom[0]
            dy = right_bottom[1] - left_bottom[1]
            angle = np.arctan2(dy, dx) * 180 / np.pi
            #print("test11113")
            # Combine position and angle for steering
            position_weight = 0.5
            angle_weight = 0.5
            max_angle = 30
            position_factor = deviation / (self.image_width / 2)
            angle_factor = angle / 45

            steering_angle = -(position_weight * position_factor + angle_weight * angle_factor) * max_angle
            #print("test11114")
            bottom_points = {
                'left': (left_bottom[0], left_bottom[1] + roi_height),
                'right': (right_bottom[0], right_bottom[1] + roi_height),
                'angle': angle,
                'single_line': False
            }
            bottom_point = (0, 0) 

        else:  # Single line case
            active_lines = left_lines if left_lines else right_lines
            using_right_line = bool(right_lines)

            # Get bottom and top points of the line
            bottom_point = self.get_bottom_point(active_lines)
            top_point = self.get_top_point(active_lines)

            if bottom_point is None or top_point is None:
                print("Mode noline previous steering")
                return self.previous_steering_angle, image_center, image_center, 0, None

            # Calculate angle relative to vertical
            dx = top_point[0] - bottom_point[0]
            dy = top_point[1] - bottom_point[1]
            angle = np.arctan2(dx, dy) * 180 / np.pi  # Angle relative to vertical

            # Calculate horizontal distance from image center to bottom point
            distance_to_center = abs(bottom_point[0] - image_center)
            max_distance = self.image_width / 2  # Maximum possible distance

            # Calculate vertical position factor
            #vertical_position = bottom_point[1]  # y-coordinate of bottom point
           
        
            max_vertical = self.image_height/4  # maximum y-value in ROI    
            #print(f"positions top 0: {top_point[0]:.2f}")
            #print(f"positions top 1: {top_point[1]:.2f}")
            #print(f"positions bottom 0: {bottom_point[0]:.2f}")
            #print(f"positions bottom 1: {bottom_point[1]:.2f}")
            vertical_position = (self.image_height/2) - bottom_point[1]  #distance from bottom to line in y
            vertical_factor = vertical_position / max_vertical  # 0 when at bottom, 1 when in the middle or higher
            distance_factor = 0
            # Calculate the target angle in steps:
            if using_right_line:
                print("Mode right line detected")
                if vertical_factor > 0.1:
                    # When line is not at bottom, prioritize vertical alignment
                    # Target goes from -100° (vertical_factor=1) to -145° (vertical_factor=0)
                    target_angle = -120 - (25 * (1 - vertical_factor))
                else:
                    # When line is at bottom, use horizontal distance
                    # Target goes from -145° (distance_factor=1) to -190° (distance_factor=0)
                    distance_factor = distance_to_center / max_distance
                    target_angle = -190 + (45 * distance_factor)
            else:
                print("Mode left line detected")
                if vertical_factor > 0.1:
                    # When line is not at bottom, prioritize vertical alignment
                    # Target goes from 100° (vertical_factor=1) to 145° (vertical_factor=0)
                    target_angle = 120 + (25 * (1 - vertical_factor))
                else:
                    # When line is at bottom, use horizontal distance
                    # Target goes from 145° (distance_factor=1) to 190° (distance_factor=0)
                    distance_factor = distance_to_center / max_distance
                    target_angle = 190 - (45 * distance_factor)

            #print(f"Distance to center: {distance_to_center:.2f}")
            #print(f"Vertical position: {vertical_position:.2f}")
            #print(f"Vertical factor: {vertical_factor:.2f}")
            #print(f"distance factor: {distance_factor:.2f}")
            print(f"Target angle: {target_angle:.1f}")

            steering_angle = -(angle - target_angle)
            steering_angle *= 0.5  # Proportional gain

            # Limit steering angle
            max_angle = 30
            steering_angle = np.clip(steering_angle, -max_angle, max_angle)

            # Calculate deviation for visualization
            deviation = bottom_point[0] - image_center

            bottom_points = {
                'single_line': True,
                'line_angle': angle,
                'bottom_point': (bottom_point[0], bottom_point[1] + roi_height),
                'top_point': (top_point[0], top_point[1] + roi_height),
                'using_right_line': using_right_line,
                'target_angle': target_angle,
                'distance_factor': distance_factor,
                'distance_to_center': distance_to_center,
                'vertical_factor': vertical_factor,
                'vertical_position': vertical_position
            }

        self.previous_steering_angle = steering_angle
        return steering_angle, bottom_point[0], image_center, deviation, bottom_points

    def get_bottom_point(self, lines):
        """Find the point with maximum y value (bottom-most point)"""
        max_y = -float('inf')
        bottom_point = None
        for line in lines:
            x1, y1, x2, y2 = line
            if y1 > max_y:
                max_y = y1
                bottom_point = (x1, y1)
            if y2 > max_y:
                max_y = y2
                bottom_point = (x2, y2)
        return bottom_point

    def get_top_point(self, lines):
        """Find the point with minimum y value (top-most point)"""
        min_y = float('inf')
        top_point = None
        for line in lines:
            x1, y1, x2, y2 = line
            if y1 < min_y:
                min_y = y1
                top_point = (x1, y1)
            if y2 < min_y:
                min_y = y2
                top_point = (x2, y2)
        return top_point

        
    def save_images(self, original, standard, probabilistic, timestamp, steering_angle):
        # Save original image
        cv2.imwrite(
            os.path.join(self.save_dir, 'original', f'frame_{timestamp}.jpg'),
            original
        )
        
        # Save processed images
        cv2.imwrite(
            os.path.join(self.save_dir, 'processed', f'frame_{timestamp}_standard.jpg'),
            standard
        )
        
        cv2.imwrite(
            os.path.join(self.save_dir, 'processed', f'frame_{timestamp}_probabilistic.jpg'),
            probabilistic
        )
        

        
    def process_frame(self):
        # Capture frame
        image = self.camera.value

        # Preprocess image
        gray, blurred, binary, binary_init, road = self.preprocess_image(image)

        # Detect lines
        left_lines, right_lines, roi_height, roi = self.detect_lines(binary)
        #print("test11")
        steering_angle, center_x, image_center, deviation, bottom_points = self.calculate_steering_angle(
        left_lines, right_lines, roi_height, road)
     

        # Visualize results
        visualization = image.copy()

        if left_lines or right_lines:
            # Draw all detected lines
            # Draw left lines in blue
            for line in left_lines:
                x1, y1, x2, y2 = line
                cv2.line(visualization, 
                        (x1, y1 + roi_height), 
                        (x2, y2 + roi_height), 
                        (255, 0, 0), 2)  # Blue color

            # Draw right lines in red
            for line in right_lines:
                x1, y1, x2, y2 = line
                cv2.line(visualization, 
                        (x1, y1 + roi_height), 
                        (x2, y2 + roi_height), 
                        (0, 0, 255), 2)  # Red color

            if bottom_points:
                bottom_y = self.image_height - 20  # Define bottom_y here for all cases

                if bottom_points.get('single_line', False):
                    # Single line visualization
                    # Draw bottom and top points
                    bottom = bottom_points['bottom_point']
                    top = bottom_points['top_point']

                    cv2.circle(visualization, bottom, 5, (255, 255, 0), -1)  # Yellow
                    cv2.circle(visualization, top, 5, (255, 255, 0), -1)  # Yellow

                    # Draw line between top and bottom points
                    cv2.line(visualization,
                            bottom,
                            top,
                            (0, 255, 255), 2)  # Yellow

                    # Draw vertical reference line
                    cv2.line(visualization,
                            (image_center, bottom[1]),
                            (image_center, top[1]),
                            (0, 255, 0), 1)  # Green line

                    # Add text for single line mode
                    cv2.putText(visualization,
                               f"Mode: {'Right' if bottom_points['using_right_line'] else 'Left'} Line Only",
                               (10, bottom_y - 85),
                               cv2.FONT_HERSHEY_SIMPLEX,
                               0.5,
                               (255, 255, 255),
                               1)
                    # Add visualization for adaptive target angle
                    if 'target_angle' in bottom_points:
                        # Draw current line angle
                        cv2.putText(visualization,
                                   f"Current Angle: {bottom_points['line_angle']:.1f}°",
                                   (10, bottom_y - 105),
                                   cv2.FONT_HERSHEY_SIMPLEX,
                                   0.5,
                                   (255, 255, 255),
                                   1)

                        # Draw target angle
                        cv2.putText(visualization,
                                   f"Target Angle: {bottom_points['target_angle']:.1f}°",
                                   (10, bottom_y - 125),
                                   cv2.FONT_HERSHEY_SIMPLEX,
                                   0.5,
                                   (255, 255, 255),
                                   1)

                        # In the visualization part:
                        cv2.putText(visualization,
                                   f"Dist to Center: {bottom_points['distance_to_center']:.0f}px",
                                   (10, bottom_y - 165),
                                   cv2.FONT_HERSHEY_SIMPLEX,
                                   0.5,
                                   (255, 255, 255),
                                   1)

                        cv2.putText(visualization,
                                   f"Vert Factor: {bottom_points['vertical_factor']:.2f}",
                                   (10, bottom_y - 145),
                                   cv2.FONT_HERSHEY_SIMPLEX,
                                   0.5,
                                   (255, 255, 255),
                                   1)

                        cv2.putText(visualization,
                                   f"Dist Factor: {bottom_points['distance_factor']:.2f}",
                                   (10, bottom_y - 125),
                                   cv2.FONT_HERSHEY_SIMPLEX,
                                   0.5,
                                   (255, 255, 255),
                                   1)
                        # Draw target angle line
                        arrow_length = 40
                        target_angle_rad = np.radians(bottom_points['target_angle'])
                        target_x = int(arrow_length * np.sin(target_angle_rad))
                        target_y = int(arrow_length * np.cos(target_angle_rad))

                        cv2.line(visualization,
                                (image_center, bottom_y - 60),
                                (image_center + target_x, bottom_y - 60 - target_y),
                                (0, 255, 0),  # Green color for target
                                1)
                else:
                    # Dual line visualization
                    cv2.circle(visualization, bottom_points['left'], 5, (255, 255, 0), -1)  # Yellow
                    cv2.circle(visualization, bottom_points['right'], 5, (255, 255, 0), -1)  # Yellow

                    # Draw line between bottom points
                    cv2.line(visualization,
                            bottom_points['left'],
                            bottom_points['right'],
                            (0, 255, 255), 2)  # Yellow

                    # Draw horizontal reference line
                    mid_y = (bottom_points['left'][1] + bottom_points['right'][1]) // 2
                    left_x = min(bottom_points['left'][0], bottom_points['right'][0])
                    right_x = max(bottom_points['left'][0], bottom_points['right'][0])
                    cv2.line(visualization,
                        (left_x, mid_y),
                        (right_x, mid_y),
                        (0, 255, 0), 1)  # Green line

                # Draw correction visualization (common for both modes)
                # Draw image center line
                cv2.line(visualization,
                        (image_center, bottom_y - 40),
                        (image_center, bottom_y),
                        (255, 255, 0), 2)

                # Draw detected center point
                cv2.line(visualization,
                        (center_x, bottom_y - 40),
                        (center_x, bottom_y),
                        (0, 255, 0), 2)

                # Draw deviation line
                cv2.line(visualization,
                        (image_center, bottom_y - 20),
                        (center_x, bottom_y - 20),
                        (255, 0, 255), 2)

                # Add text annotations
                cv2.putText(visualization,
                           f"Deviation: {deviation}px",
                           (10, bottom_y - 65),
                           cv2.FONT_HERSHEY_SIMPLEX,
                           0.5,
                           (255, 255, 255),
                           1)

                angle_value = bottom_points.get('line_angle' if bottom_points.get('single_line', False) else 'angle', 0)
                cv2.putText(visualization,
                           f"Angle: {angle_value:.1f} deg",
                           (10, bottom_y - 45),
                           cv2.FONT_HERSHEY_SIMPLEX,
                           0.5,
                           (255, 255, 255),
                           1)

                cv2.putText(visualization,
                           f"Steering: {steering_angle:.1f} deg",
                           (10, bottom_y - 25),
                           cv2.FONT_HERSHEY_SIMPLEX,
                           0.5,
                           (255, 255, 255),
                           1)

                # Draw steering direction arrow
                arrow_length = 40
                arrow_angle = np.radians(steering_angle)
                arrow_x = int(arrow_length * np.sin(arrow_angle))
                arrow_y = int(arrow_length * np.cos(arrow_angle))

                arrow_start = (image_center, bottom_y - 60)
                arrow_end = (image_center + arrow_x, bottom_y - 60 - arrow_y)

                cv2.arrowedLine(visualization,
                              arrow_start,
                              arrow_end,
                              (0, 255, 255),
                              2,
                              tipLength=0.3)

        return steering_angle, {
            'original': cv2.cvtColor(image, cv2.COLOR_BGR2RGB),
            'grayscale': gray,
            'blurred': blurred,
            'binary': binary_init,
            'roi': roi,
            'result': cv2.cvtColor(visualization, cv2.COLOR_BGR2RGB)
        }
    def stop(self):
        self.camera.stop()

def plot_processing_steps(images, steering_angle):
    fig, axes = plt.subplots(2, 3, figsize=(15, 10))
    fig.suptitle(f'Line Detection Processing Steps (Steering Angle: {steering_angle:.2f}°)', fontsize=16)
    
    # Plot original image
    axes[0, 0].imshow(images['original'])
    axes[0, 0].set_title('Original Image')
    axes[0, 0].axis('off')
    
    # Plot grayscale image
    axes[0, 1].imshow(images['grayscale'], cmap='gray')
    axes[0, 1].set_title('Grayscale')
    axes[0, 1].axis('off')
    
    # Plot blurred image
    axes[0, 2].imshow(images['blurred'], cmap='gray')
    axes[0, 2].set_title('Gaussian Blur')
    axes[0, 2].axis('off')
    
    # Plot binary image
    axes[1, 0].imshow(images['binary'], cmap='gray')
    axes[1, 0].set_title('Binary Threshold')
    axes[1, 0].axis('off')
    
    # Plot ROI
    axes[1, 1].imshow(images['roi'], cmap='gray')
    axes[1, 1].set_title('Region of Interest')
    axes[1, 1].axis('off')
    
    # Plot final result with detected lines
    axes[1, 2].imshow(images['result'])
    axes[1, 2].set_title('Detected Lines')
    axes[1, 2].axis('off')
    
    plt.tight_layout()
    plt.show()

# %%
class PIDController:
    def __init__(self, kp, ki, kd):
        self.kp = kp
        self.ki = ki
        self.kd = kd
        
        self.previous_error = 0
        self.integral = 0
        
    def compute(self, error, dt):
        """
        Compute PID control value based on error and time step
        """
        # Proportional term
        p_term = self.kp * error
        
        # Integral term
        self.integral += error * dt
        i_term = self.ki * self.integral
        
        # Derivative term
        derivative = (error - self.previous_error) / dt
        d_term = self.kd * derivative
        
        # Save error for next iteration
        self.previous_error = error
        
        # Compute total control value
        control = p_term + i_term + d_term
        
        return control
        
    def reset(self):
        """Reset the PID controller"""
        self.previous_error = 0
        self.integral = 0

# %%
 from IPython.display import clear_output
class LineFollower:
    def __init__(self, robot, camera, base_speed=0.3):
        # Initialize robot and camera
        #self.robot = Robot()
        #self.camera = Camera.instance(width=224, height=224)
        self.robot = robot
        self.camera = camera
        self.detector = LineDetector(camera = self.camera)
        
        # PID controller for steering
        # Adjust these values based on testing
        self.pid = PIDController(kp=0.03, ki=0.0008, kd=0.001)
        
        # Motor control parameters
        self.base_speed = base_speed
        self.max_steering = 0.2  # Maximum steering adjustment
        
        # Time tracking for PID
        self.previous_time = time.time()
        
    def steer(self, steering_value):
        """
        Convert steering value to motor commands
        steering_value should be between -1 and 1
        """
        # Clip steering value
        steering_value = np.clip(steering_value, -1, 1)
        
        # Calculate motor values
        if steering_value >= 0:
            # Turning right
            left_speed = self.base_speed
            right_speed = self.base_speed * (1 - steering_value)
        else:
            # Turning left
            left_speed = self.base_speed * (1 + steering_value)
            right_speed = self.base_speed
            
        print(f"Left speed: {left_speed}")
        print(f"Right speed: {right_speed}")
        # Apply motor values
        self.robot.left_motor.value = float(left_speed)
        self.robot.right_motor.value = float(right_speed)
        
    def follow_line(self):
        """Main line following loop"""
        try:
            while True:
                # Calculate time step
                current_time = time.time()
                dt = current_time - self.previous_time
                self.previous_time = current_time
                
                # Get steering angle from your existing line detection code
                steering_angle, images = self.detector.process_frame()
                #print("test1")
                #clear_output(wait=True)
                #plot_processing_steps(images, steering_angle)
                #steering_angle, visualization = self.process_frame()  # Your existing method
                print(f"steering angel: {steering_angle}")
                # Convert steering angle to normalized error (-1 to 1)
                error = steering_angle / 30.0  # Assuming max steering angle is 30 degrees
                #print(f"error : {error}")
                # Compute PID control value
                control_value = self.pid.compute(steering_angle, dt)
                #print(f"controller : {control_value}")
                # Apply steering
                self.steer(control_value)
                
                # Optional: Display visualization
                #cv2.imshow('Line Following', images['result'])
                time.sleep(0.3)
                
                #if cv2.waitKey(1) & 0xFF == ord('q'):
                 #   break
                
                
        except KeyboardInterrupt:
            print("Stopping robot...")
        finally:
            # Stop the robot
            self.robot.stop()
            cv2.destroyAllWindows()
            self.camera.stop()
    
    def stop(self):
        """Stop the robot"""
        self.robot.left_motor.value = 0.0
        self.robot.right_motor.value = 0.0

# %%
    robot = Robot()
    camera = Camera.instance(width=224, height=224)
    follower = LineFollower(robot, camera,base_speed=0.3)
   
    try:
        # Start line following
        follower.follow_line()
    except Exception as e:
        print(f"Error: {e}")
    finally:
        # Make sure robot stops
        follower.stop()
        camera.stop()
        robot.stop()
# Out:
# small raod: 1989.857142857143
# Mode left line detected
# Target angle: 145.0
# steering angel: 6.168652929561901
# Left speed: 0.4
# Right speed: 0.0
# small raod: 3854.0
# Mode 2 lines detected
# steering angel: -4.269866754236967
# Left speed: 0.3381062854165528
# Right speed: 0.4
# small raod: 1541.8333333333333
# Mode left line detected
# Target angle: 146.2
# steering angel: 2.620435020802006
# Left speed: 0.4
# Right speed: 0.36270662810522786
# small raod: 979.3333333333334
# Mode 2 lines detected
# steering angel: 2.2088701748879638
# Left speed: 0.4
# Right speed: 0.3738109141135011
# small raod: 2195.6666666666665
# Mode left line detected
# Target angle: 147.4
# steering angel: 3.60814268898973
# Left speed: 0.4
# Right speed: 0.3546561839137615
# small raod: 1758.3333333333333
# Mode left line detected
# Target angle: 149.0
# steering angel: 4.004425592681301
# Left speed: 0.4
# Right speed: 0.35052248045164985
# small raod: 750.25
# Mode 2 lines detected
# steering angel: 2.485207118541989
# Left speed: 0.4
# Right speed: 0.370624967651157
# small raod: 380.0
# Mode 2 lines detected
# steering angel: -3.2557808734016533
# Left speed: 0.3551400228279238
# Right speed: 0.4
# small raod: 585.6666666666666
# Mode right line detected
# Target angle: -137.9
# steering angel: -3.4826275171393632
# Left speed: 0.3584737946979833
# Right speed: 0.4
# small raod: 700.0
# Mode 2 lines detected
# steering angel: -2.6001895101132897
# Left speed: 0.370120036433203
# Right speed: 0.4
# small raod: 297.75
# Mode 2 lines detected
# steering angel: 0.3052118102132831
# Left speed: 0.4
# Right speed: 0.39254628111593515
# small raod: 365.25
# Mode 2 lines detected
# steering angel: 3.0235679887748184
# Left speed: 0.4
# Right speed: 0.35986497193448264
# small raod: 791.0
# Mode left line detected
# Target angle: 134.3
# steering angel: 3.7979957266192272
# Left speed: 0.4
# Right speed: 0.35246942057855174
# small raod: 410.0
# Mode 2 lines detected
# steering angel: 2.18150128888009
# Left speed: 0.4
# Right speed: 0.37452803429004744
# small raod: 569.0
# Mode right line detected
# Target angle: -124.5
# steering angel: -3.949617268603866
# Left speed: 0.34603836022769524
# Right speed: 0.4
# small raod: 798.5
# Mode right line detected
# Target angle: -132.1
# steering angel: -4.774791236504463
# Left speed: 0.3420302924768749
# Right speed: 0.4
# small raod: 781.0
# Mode right line detected
# Target angle: -133.4
# steering angel: -2.254180354571261
# Left speed: 0.3760695094655329
# Right speed: 0.4
# small raod: 666.5
# Mode 2 lines detected
# steering angel: -1.4893853339984626
# Left speed: 0.38297908560053623
# Right speed: 0.4
# small raod: 631.0
# Mode 2 lines detected
# steering angel: 0.5620764120288306
# Left speed: 0.4
# Right speed: 0.39080948423485307
# small raod: 672.0
# Mode left line detected
# Target angle: 127.1
# steering angel: 2.3551499481988927
# Left speed: 0.4
# Right speed: 0.3693843240572875
# small raod: 640.5
# Mode 2 lines detected
# steering angel: 1.5018870623075515
# Left speed: 0.4
# Right speed: 0.3826171976528617
# small raod: 377.3333333333333
# Mode 2 lines detected
# steering angel: -0.12414481688078272
# Left speed: 0.3969266616246101
# Right speed: 0.4
# small raod: 389.6666666666667
# Mode right line detected
# Target angle: -127.6
# steering angel: -3.010157292483683
# Left speed: 0.36049680155928904
# Right speed: 0.4
# small raod: 371.3333333333333
# Mode right line detected
# Target angle: -129.4
# steering angel: -6.303745540351905
# Left speed: 0.3197523873161412
# Right speed: 0.4
# small raod: 259.75
# Mode right line detected
# Target angle: -125.8
# steering angel: -6.484958625326939
# Left speed: 0.32067480675334337
# Right speed: 0.4
# small raod: 192.2
# Mode right line detected
# Target angle: -123.1
# steering angel: -6.766359054474236
# Left speed: 0.31646599041408946
# Right speed: 0.4
# small raod: 558.5
# Mode right line detected
# Target angle: -122.2
# steering angel: -6.769553341442325
# Left speed: 0.3160608114204482
# Right speed: 0.4
# small raod: 585.5
# Mode right line detected
# Target angle: -123.1
# steering angel: -4.903645806622464
# Left speed: 0.3402107481613009
# Right speed: 0.4
# small raod: 624.5
# Mode 2 lines detected
# steering angel: 0.13392857142857142
# Left speed: 0.4
# Right speed: 0.39543168220435343
# small raod: 644.0
# Mode 2 lines detected
# steering angel: 0.7332391903954125
# Left speed: 0.4
# Right speed: 0.3936164331428529
# small raod: 642.5
# Mode 2 lines detected
# steering angel: -0.2942192691716878
# Left speed: 0.3920714415099879
# Right speed: 0.4
# small raod: 674.5
# Mode 2 lines detected
# steering angel: -1.234029919450409
# Left speed: 0.3807885151964834
# Right speed: 0.4
# small raod: 471.6666666666667
# Mode 2 lines detected
# steering angel: -1.6593052949465645
# Left speed: 0.37611084976809983
# Right speed: 0.4
# small raod: 463.0
# Mode 2 lines detected
# steering angel: -1.3192073766863681
# Left speed: 0.3809778474482888
# Right speed: 0.4
# small raod: 664.5
# Mode 2 lines detected
# steering angel: -0.21328032057475332
# Left speed: 0.395158710762622
# Right speed: 0.4
# small raod: 684.0
# Mode 2 lines detected
# steering angel: 0.9897943478245026
# Left speed: 0.4
# Right speed: 0.3901751646032572
# small raod: 489.3333333333333
# Mode 2 lines detected
# steering angel: 2.020422518149398
# Left speed: 0.4
# Right speed: 0.377842392220732
# small raod: 474.6666666666667
# Mode 2 lines detected
# steering angel: 1.7572424768556054
# Left speed: 0.4
# Right speed: 0.3823442641929611
# small raod: 339.5
# Mode 2 lines detected
# steering angel: 0.04828522992740106
# Left speed: 0.39538655881295787
# Right speed: 0.4
# small raod: 250.33333333333334
# Mode 2 lines detected
# steering angel: -2.0567250316765366
# Left speed: 0.3694945240597305
# Right speed: 0.4
# small raod: 354.2
# Mode 2 lines detected
# steering angel: -3.2377503416467617
# Left speed: 0.3560533730545202
# Right speed: 0.4
# small raod: 283.3333333333333
# Mode 2 lines detected
# steering angel: -2.4314220025769515
# Left speed: 0.3678532811609685
# Right speed: 0.4
# small raod: 250.25
# Mode left line detected
# Target angle: 121.8
# steering angel: 2.4899629779572408
# Left speed: 0.4
# Right speed: 0.3678658975908121
# small raod: 212.83333333333334
# Mode left line detected
# Target angle: 126.7
# steering angel: 4.3119708177878024
# Left speed: 0.4
# Right speed: 0.3492846607098473
# small raod: 261.0
# Mode left line detected
# Target angle: 124.5
# steering angel: 8.644191049269487
# Left speed: 0.4
# Right speed: 0.2933266327199043
# small raod: 122.81818181818181
# Mode left line detected
# Target angle: 114.2
# steering angel: 7.295612208207814
# Left speed: 0.4
# Right speed: 0.3156015658402902
# small raod: 234.2
# Mode left line detected
# Target angle: 117.3
# steering angel: 6.160055055478544
# Left speed: 0.4
# Right speed: 0.3282529860355692
# small raod: 630.0
# Mode left line detected
# Target angle: 124.0
# steering angel: 4.117476159917906
# Left speed: 0.4
# Right speed: 0.35342343576785107
# small raod: 241.8
# Mode 2 lines detected
# steering angel: 1.7645192982543243
# Left speed: 0.4
# Right speed: 0.38190983924219957
# small raod: 192.2
# Mode 2 lines detected
# steering angel: 0.4406903719540339
# Left speed: 0.4
# Right speed: 0.3964900780898313
# small raod: 347.5
# Mode 2 lines detected
# steering angel: -0.3472088920033247
# Left speed: 0.3946641122397667
# Right speed: 0.4
# small raod: 296.0
# Mode left line detected
# Target angle: 114.2
# steering angel: -2.7136600898726186
# Left speed: 0.3643648245643785
# Right speed: 0.4
# small raod: 160.0
# Mode left line detected
# Target angle: 114.6
# steering angel: -1.176490625614747
# Left speed: 0.3871472565687751
# Right speed: 0.4
# small raod: 153.0
# Mode left line detected
# Target angle: 116.9
# steering angel: -0.48628912989408946
# Left speed: 0.39432474110782334
# Right speed: 0.4
# small raod: 427.0
# Mode 2 lines detected
# steering angel: 7.748783382147372
# Left speed: 0.4
# Right speed: 0.29671384775649096
# small raod: 453.0
# Mode left line detected
# Target angle: 115.5
# steering angel: 9.430622619298347
# Left speed: 0.4
# Right speed: 0.2838330888965972
# small raod: 770.6666666666666
# Mode left line detected
# Target angle: 128.5
# steering angel: 9.002809917130023
# Left speed: 0.4
# Right speed: 0.29026091581883046
# small raod: 964.3333333333334
# Mode left line detected
# Target angle: 145.4
# steering angel: 9.197653603962749
# Left speed: 0.4
# Right speed: 0.2861849677794068
# small raod: 1616.0
# Mode left line detected
# Target angle: 145.0
# steering angel: 2.460196069992719
# Left speed: 0.4
# Right speed: 0.3748559420431363
# small raod: 161.5
# Mode left line detected
# Target angle: 116.9
# steering angel: -8.288421150511027
# Left speed: 0.29124043676196204
# Right speed: 0.4
# small raod: 196.0
# Mode left line detected
# Target angle: 116.9
# steering angel: -2.5165534678265757
# Left speed: 0.37908155397500853
# Right speed: 0.4
# small raod: 398.0
# Mode left line detected
# Target angle: 124.5
# steering angel: 1.3524028147364504
# Left speed: 0.4
# Right speed: 0.376562894909349
# small raod: 557.5
# Mode left line detected
# Target angle: 129.4
# steering angel: 2.7119528358273612
# Left speed: 0.4
# Right speed: 0.3631451324753955
# small raod: 526.5
# Mode left line detected
# Target angle: 129.8
# steering angel: 1.3741776270590833
# Left speed: 0.4
# Right speed: 0.3821348112966962
# small raod: 431.0
# Mode left line detected
# Target angle: 126.7
# steering angel: -0.5396278672630572
# Left speed: 0.3939582777454915
# Right speed: 0.4
# small raod: 402.5
# Mode left line detected
# Target angle: 125.8
# steering angel: -0.3537423454619315
# Left speed: 0.39872372640400433
# Right speed: 0.4
# small raod: 902.0
# Mode left line detected
# Target angle: 127.6
# steering angel: 1.0569768430378588
# Left speed: 0.4
# Right speed: 0.3827317431429882
# small raod: 1010.0
# Mode left line detected
# Target angle: 129.4
# steering angel: 1.4528828049740596
# Left speed: 0.4
# Right speed: 0.37912353118027486
# small raod: 918.0
# Mode left line detected
# Target angle: 128.9
# steering angel: -0.0826437288290407
# Left speed: 0.4
# Right speed: 0.39982740774720127
# small raod: 858.0
# Mode left line detected
# Target angle: 127.1
# steering angel: -0.028477486480589675
# Left speed: 0.4
# Right speed: 0.39724879312897643
# small raod: 304.3333333333333
# Mode left line detected
# Target angle: 126.7
# steering angel: 0.07572812430301212
# Left speed: 0.4
# Right speed: 0.3959292513252741
# small raod: 189.6
# Mode left line detected
# Target angle: 126.7
# steering angel: 0.22129541699188593
# Left speed: 0.4
# Right speed: 0.3941238170889828
# small raod: 188.2
# Mode left line detected
# Target angle: 125.8
# steering angel: 0.19325807605199685
# Left speed: 0.4
# Right speed: 0.39463431464255655
# small raod: 158.0
# Mode left line detected
# Target angle: 125.8
# steering angel: 0.31856769638925897
# Left speed: 0.4
# Right speed: 0.39291131363282233
# small raod: 159.83333333333334
# Mode left line detected
# Target angle: 124.9
# steering angel: -0.11173938560068564
# Left speed: 0.4
# Right speed: 0.39876097135651495
# small raod: 174.6
# Mode left line detected
# Target angle: 125.4
# steering angel: 0.08419986256946288
# Left speed: 0.4
# Right speed: 0.39565952751546046
# small raod: 149.42857142857142
# Mode left line detected
# Target angle: 124.5
# steering angel: -0.03790259639257698
# Left speed: 0.4
# Right speed: 0.3974966933447419
# small raod: 275.9166666666667
# Mode left line detected
# Target angle: 173.1
# steering angel: 1.1988008886001609
# Left speed: 0.4
# Right speed: 0.38085688558597175
# small raod: 411.2352941176471
# Mode left line detected
# Target angle: 145.0
# steering angel: 6.746296580428023
# Left speed: 0.4
# Right speed: 0.3087005301522326
# small raod: 617.0625
# Mode left line detected
# Target angle: 145.0
# steering angel: 7.118197399529407
# Left speed: 0.4
# Right speed: 0.3093382144396339
# small raod: 555.25
# Mode left line detected
# Target angle: 145.0
# steering angel: 6.101299080882896
# Left speed: 0.4
# Right speed: 0.3221830605086461
# small raod: 264.125
# Mode 2 lines detected
# steering angel: 9.123755478932873
# Left speed: 0.4
# Right speed: 0.2806224940614496
# small raod: 238.14285714285714
# Mode 2 lines detected
# steering angel: -5.243191777054356
# Left speed: 0.32709133101941656
# Right speed: 0.4
# small raod: 835.5
# Mode 2 lines detected
# steering angel: -7.277334096103645
# Left speed: 0.3156472975630538
# Right speed: 0.4
# small raod: 825.0
# Mode left line detected
# Target angle: 179.6
# steering angel: 11.10646173428863
# Left speed: 0.4
# Right speed: 0.23955547317842607
# small raod: 868.5
# Mode left line detected
# Target angle: 173.5
# steering angel: 8.522373693988982
# Left speed: 0.4
# Right speed: 0.2930648929846015
# small raod: 915.75
# Mode 2 lines detected
# steering angel: 7.314507868517998
# Left speed: 0.4
# Right speed: 0.30522448241884226
# small raod: 1039.6666666666667
# Mode 2 lines detected
# steering angel: -7.742530672123703
# Left speed: 0.2971992994817355
# Right speed: 0.4
# small raod: 9013.5
# Mode 2 lines detected
# steering angel: -4.625511618491356
# Left speed: 0.3548767468746913
# Right speed: 0.4
# small raod: 9776.0
# Mode right line detected
# Target angle: -145.8
# steering angel: 2.114843350408435
# Left speed: 0.4
# Right speed: 0.3613069401250837
# small raod: 12971.0
# Mode 2 lines detected
# steering angel: -12.534029139592452
# Left speed: 0.2409427128128371
# Right speed: 0.4
# small raod: 16184.0
# Mode right line detected
# Target angle: -151.4
# steering angel: -8.214285714285722
# Left speed: 0.3099585080938254
# Right speed: 0.4
# small raod: 13407.0
# Mode right line detected
# Target angle: -149.8
# steering angel: -7.410714285714278
# Left speed: 0.3152553595357246
# Right speed: 0.4
# small raod: 2466.5
# Mode right line detected
# Target angle: -156.2
# steering angel: 8.535056968388716
# Left speed: 0.4
# Right speed: 0.2780208275020187
# small raod: 3948.0
# Mode 2 lines detected
# steering angel: -8.31148525445786
# Left speed: 0.28565948688107873
# Right speed: 0.4
# small raod: 1066.3333333333333
# Mode left line detected
# Target angle: 154.6
# steering angel: 9.324694143287275
# Left speed: 0.4
# Right speed: 0.26709961212342626
# small raod: 836.1666666666666
# Mode left line detected
# Target angle: 163.9
# steering angel: 2.975914066919387
# Left speed: 0.4
# Right speed: 0.3661454636387361
# small raod: 446.38461538461536
# Mode 2 lines detected
# steering angel: -0.12278115668096667
# Left speed: 0.4
# Right speed: 0.3996216359618183
# small raod: 384.1
# Mode 2 lines detected
# steering angel: 2.678571428571429
# Left speed: 0.4
# Right speed: 0.35917242985331665
# small raod: 431.6666666666667
# Mode 2 lines detected
# steering angel: -2.0174002920225527
# Left speed: 0.37578495383494487
# Right speed: 0.4
# small raod: 125.0
# Mode right line detected
# Target angle: -111.5
# steering angel: 3.16486055846552
# Left speed: 0.4
# Right speed: 0.35021558030006184
# big raod: 69.0
# Mode 2 lines detected
# steering angel: -0.7219372049673596
# Left speed: 0.39226268281654736
# Right speed: 0.4
# small raod: 73.71428571428571
# Mode right line detected
# Target angle: -111.1
# steering angel: 3.2629336486075857
# Left speed: 0.4
# Right speed: 0.35001672624291963
# small raod: 78.8
# Mode right line detected
# Target angle: -107.1
# steering angel: 2.663281811694077
# Left speed: 0.4
# Right speed: 0.36249937151961925
# small raod: 89.0
# Mode right line detected
# Target angle: -112.9
# steering angel: -3.05069696397193
# Left speed: 0.36224326357416226
# Right speed: 0.4
# small raod: 235.0
# Mode right line detected
# Target angle: -116.0
# steering angel: -3.199074543447331
# Left speed: 0.36704402365564737
# Right speed: 0.4
# small raod: 76.11111111111111
# Mode right line detected
# Target angle: -117.3
# steering angel: -1.4147637715985013
# Left speed: 0.39067833798210877
# Right speed: 0.4
# small raod: 75.2
# Mode right line detected
# Target angle: -116.4
# steering angel: 0.5483271575864492
# Left speed: 0.4
# Right speed: 0.3854770957483109
# small raod: 72.125
# Mode right line detected
# Target angle: -115.5
# steering angel: 0.6802613398895545
# Left speed: 0.4
# Right speed: 0.38608542573239163
# small raod: 80.44444444444444
# Mode right line detected
# Target angle: -116.4
# steering angel: 0.5767288896128662
# Left speed: 0.4
# Right speed: 0.3875540282635298
# small raod: 81.5
# Mode right line detected
# Target angle: -117.8
# steering angel: 1.454711439469655
# Left speed: 0.4
# Right speed: 0.37565334623548735
# big raod: 69.33333333333333
# Mode right line detected
# Target angle: -120.4
# steering angel: -1.7168816117450163
# Left speed: 0.38112863053427226
# Right speed: 0.4
# small raod: 91.38709677419355
# Mode 2 lines detected
# steering angel: -12.18510436323012
# Left speed: 0.24559659383675303
# Right speed: 0.4
# small raod: 968.1
# Mode 2 lines detected
# steering angel: 2.962581455072583
# Left speed: 0.4
# Right speed: 0.3419861711990777
# small raod: 2121.8571428571427
# Mode 2 lines detected
# steering angel: -5.151283953464369
# Left speed: 0.33399964280739874
# Right speed: 0.4
# small raod: 4496.0
# Mode 2 lines detected
# steering angel: 2.5378225446062066
# Left speed: 0.4
# Right speed: 0.35819470636067763
# small raod: 785.6
# Mode 2 lines detected
# steering angel: 0.7332391903954125
# Left speed: 0.4
# Right speed: 0.3883128172758592
# small raod: 10572.0
# Mode 2 lines detected
# steering angel: 1.24604080549968
# Left speed: 0.4
# Right speed: 0.3799041789980023
# small raod: 25088.0
# Mode 2 lines detected
# steering angel: 3.3574346264034807
# Left speed: 0.4
# Right speed: 0.35255414424212606
# small raod: 20809.0
# Mode right line detected
# Target angle: -146.6
# steering angel: -13.050505307709507
# Left speed: 0.23327628124008326
# Right speed: 0.4
# small raod: 14176.0
# Mode right line detected
# Target angle: -155.4
# steering angel: 0.3674604644188406
# Left speed: 0.4
# Right speed: 0.3815650957705461
# small raod: 17098.0
# Mode right line detected
# Target angle: -164.3
# steering angel: -16.45359949491582
# Left speed: 0.18807459165143678
# Right speed: 0.4
# big raod: 22.0
# steering angel: -16.45359949491582
# Left speed: 0.20057136599941902
# Right speed: 0.4
# small raod: 365.54545454545456
# Mode 2 lines detected
# steering angel: -0.5350841710199221
# Left speed: 0.4
# Right speed: 0.3885013139724005
# small raod: 681.4
# Mode left line detected
# Target angle: 169.9
# steering angel: 13.954723364109455
# Left speed: 0.4
# Right speed: 0.21654049401467496
# small raod: 492.8
# Mode left line detected
# Target angle: 171.9
# steering angel: 7.214732415015035
# Left speed: 0.4
# Right speed: 0.3209521162362113
# small raod: 567.4
# Mode left line detected
# Target angle: 171.5
# steering angel: -1.4113305084902095
# Left speed: 0.37308113183917496
# Right speed: 0.4
# small raod: 327.4
# Mode 2 lines detected
# steering angel: -0.5357142857142857
# Left speed: 0.39468714431208746
# Right speed: 0.4
# small raod: 314.0
# Mode 2 lines detected
# steering angel: 0.40178571428571425
# Left speed: 0.4
# Right speed: 0.3938843423533332
# small raod: 116.6
# Mode 2 lines detected
# steering angel: 1.508027842023119
# Left speed: 0.4
# Right speed: 0.3802808876714324
# small raod: 77.0
# steering angel: 1.508027842023119
# Left speed: 0.4
# Right speed: 0.38142557116983544
# big raod: 68.75
# Mode 2 lines detected
# steering angel: -0.037354667356140264
# Left speed: 0.39806149565499116
# Right speed: 0.4
# big raod: 46.166666666666664
# Mode 2 lines detected
# steering angel: -0.1229876770354233
# Left speed: 0.39888089862781406
# Right speed: 0.4
# big raod: 59.75
# Mode 2 lines detected
# steering angel: 0.04828522992740106
# Left speed: 0.4
# Right speed: 0.3987390245625471
# big raod: 28.2
# Mode right line detected
# Target angle: -108.4
# steering angel: -0.6084767635551955
# Left speed: 0.3924031819540188
# Right speed: 0.4
# big raod: 43.75
# Mode 2 lines detected
# steering angel: -0.037354667356140264
# Left speed: 0.4
# Right speed: 0.3993594362549325
# big raod: 21.5
# Mode left line detected
# Target angle: 107.1
# steering angel: -0.6906886971752968
# Left speed: 0.39122662292880306
# Right speed: 0.4
# big raod: 49.0
# Mode 2 lines detected
# steering angel: 0.4764675002424602
# Left speed: 0.4
# Right speed: 0.39249860427193384
# small raod: 103.0
# Mode left line detected
# Target angle: 108.4
# steering angel: -0.021045840032442698
# Left speed: 0.39953908210867206
# Right speed: 0.4
# small raod: 104.33333333333333
# Mode left line detected
# Target angle: 109.3
# steering angel: -0.5620842740448637
# Left speed: 0.39289981045418143
# Right speed: 0.4
# small raod: 167.5
# Mode left line detected
# Target angle: 109.3
# steering angel: 1.1597830885890446
# Left speed: 0.4
# Right speed: 0.3835007364772913
# small raod: 116.0
# Mode left line detected
# Target angle: 110.2
# steering angel: -0.1354880911105809
# Left speed: 0.3972176949337592
# Right speed: 0.4
# small raod: 91.25
# Mode left line detected
# Target angle: 110.6
# steering angel: 0.08772619460370379
# Left speed: 0.4
# Right speed: 0.39825881747985176
# big raod: 64.33333333333333
# Mode 2 lines detected
# steering angel: 1.24604080549968
# Left speed: 0.4
# Right speed: 0.3830845633057648
# small raod: 90.75
# Mode left line detected
# Target angle: 109.7
# steering angel: -0.41195118122030294
# Left speed: 0.39347702839172594
# Right speed: 0.4
# big raod: 58.57142857142857
# Mode 2 lines detected
# steering angel: 1.2510389274031588
# Left speed: 0.4
# Right speed: 0.38231333157365255
# big raod: 36.0
# Mode 2 lines detected
# steering angel: 0.9043057223490386
# Left speed: 0.4
# Right speed: 0.3888358567258182
# big raod: 52.76923076923077
# Mode 2 lines detected
# steering angel: 0.4764675002424602
# Left speed: 0.4
# Right speed: 0.3940330732081857
# small raod: 84.29629629629629
# Mode left line detected
# Target angle: 169.9
# steering angel: 2.856614119824897
# Left speed: 0.4
# Right speed: 0.3616748269531236
# small raod: 255.8181818181818
# Mode left line detected
# Target angle: 145.0
# steering angel: 7.6898507995626915
# Left speed: 0.4
# Right speed: 0.30004136994157776
# small raod: 355.47058823529414
# Mode 2 lines detected
# steering angel: 4.2642753599433245
# Left speed: 0.4
# Right speed: 0.3501987411214798
# big raod: 55.486486486486484
# Mode 2 lines detected
# steering angel: 4.914026395930996
# Left speed: 0.4
# Right speed: 0.3373504617524934
# small raod: 197.36363636363637
# Mode 2 lines detected
# steering angel: -3.217018735068368
# Left speed: 0.35424970520247206
# Right speed: 0.4
# small raod: 204.85714285714286
# Mode 2 lines detected
# steering angel: -5.690584155454326
# Left speed: 0.3308310475718347
# Right speed: 0.4
# small raod: 120.0
# Mode left line detected
# Target angle: 140.5
# steering angel: -5.695899389216393
# Left speed: 0.3330148801360255
# Right speed: 0.4
# small raod: 1470.8333333333333
# Mode left line detected
# Target angle: 169.9
# steering angel: 22.528129359805305
# Left speed: 0.4
# Right speed: 0.09243713153744015
# small raod: 780.0
# Mode 2 lines detected
# steering angel: 1.7627258127053516
# Left speed: 0.4
# Right speed: 0.3960875304514277
# small raod: 254.75
# Mode 2 lines detected
# steering angel: 4.204484795199895
# Left speed: 0.4
# Right speed: 0.34237634241119624
# small raod: 494.75
# Mode right line detected
# Target angle: -124.5
# steering angel: -4.2449458759272005
# Left speed: 0.34392703924880313
# Right speed: 0.4
# small raod: 1154.25
# Mode right line detected
# Target angle: -145.8
# steering angel: -9.230640561142657
# Left speed: 0.286402930970661
# Right speed: 0.4
# small raod: 649.0
# Mode right line detected
# Target angle: -162.3
# steering angel: -11.595584467155419
# Left speed: 0.25987399320056204
# Right speed: 0.4
# small raod: 365.6
# Mode 2 lines detected
# steering angel: -4.725747879087541
# Left speed: 0.35231073634374815
# Right speed: 0.4
# small raod: 523.25
# Mode left line detected
# Target angle: 123.6
# steering angel: 7.290113760712934
# Left speed: 0.4
# Right speed: 0.2960138323067562
# small raod: 472.6363636363636
# Mode left line detected
# Target angle: 150.6
# steering angel: 13.128954491939602
# Left speed: 0.4
# Right speed: 0.23222213701114902
# small raod: 553.0
# Mode 2 lines detected
# steering angel: 5.743197226688289
# Left speed: 0.4
# Right speed: 0.33533435126898586
# small raod: 223.14285714285714
# Mode 2 lines detected
# steering angel: 0.6998783088628499
# Left speed: 0.4
# Right speed: 0.39333211727391326
# small raod: 623.25
# Mode right line detected
# Target angle: -130.3
# steering angel: -4.429402795349233
# Left speed: 0.34425374032853095
# Right speed: 0.4
# small raod: 833.2
# Mode right line detected
# Target angle: -145.8
# steering angel: -10.170103593515428
# Left speed: 0.2737986275451136
# Right speed: 0.4
# small raod: 972.3333333333334
# Mode right line detected
# Target angle: -152.2
# steering angel: -5.072623723534591
# Left speed: 0.34690403949176835
# Right speed: 0.4
# small raod: 408.6666666666667
# Mode 2 lines detected
# steering angel: -0.2580733883093541
# Left speed: 0.4
# Right speed: 0.3954425521654037
# small raod: 240.875
# Mode left line detected
# Target angle: 130.3
# steering angel: 7.015572473774931
# Left speed: 0.4
# Right speed: 0.30442736704073553
# small raod: 338.0
# Mode left line detected
# Target angle: 147.8
# steering angel: 8.912806877517909
# Left speed: 0.4
# Right speed: 0.28712754365164095
# small raod: 312.85714285714283
# Mode 2 lines detected
# steering angel: 5.392455508028268
# Left speed: 0.4
# Right speed: 0.3352297636228367
# small raod: 418.25
# Mode 2 lines detected
# steering angel: -0.8593852985683101
# Left speed: 0.38637368599008726
# Right speed: 0.4
# small raod: 1013.6666666666666
# Mode right line detected
# Target angle: -135.2
# steering angel: -5.4162370142549605
# Left speed: 0.33313064049484686
# Right speed: 0.4
# small raod: 1347.6666666666667
# Mode right line detected
# Target angle: -157.1
# steering angel: -8.403216263477503
# Left speed: 0.2982703095013914
# Right speed: 0.4
# small raod: 455.0
# Mode 2 lines detected
# steering angel: -5.52958096816542
# Left speed: 0.3388920741383868
# Right speed: 0.4
# small raod: 271.2
# Mode 2 lines detected
# steering angel: 0.6047306363433175
# Left speed: 0.4
# Right speed: 0.38341894044384706
# small raod: 470.4
# Mode left line detected
# Target angle: 133.4
# steering angel: 8.109957997970206
# Left speed: 0.4
# Right speed: 0.2907703304402229
# small raod: 525.1666666666666
# Mode left line detected
# Target angle: 153.4
# steering angel: 9.633907743129
# Left speed: 0.4
# Right speed: 0.27860350828761443
# small raod: 507.5
# Mode 2 lines detected
# steering angel: 4.427921168056974
# Left speed: 0.4
# Right speed: 0.3485243660687112
# small raod: 750.3333333333334
# Mode right line detected
# Target angle: -124.0
# steering angel: -4.5632785089956585
# Left speed: 0.33829885817985894
# Right speed: 0.4
# small raod: 1622.6666666666667
# Mode right line detected
# Target angle: -146.6
# steering angel: -9.186658839847965
# Left speed: 0.2873340590772821
# Right speed: 0.4
# small raod: 1391.0
# Mode right line detected
# Target angle: -157.1
# steering angel: -9.412461779467904
# Left speed: 0.28867677269330194
# Right speed: 0.4
# small raod: 430.0
# Mode 2 lines detected
# steering angel: -3.503347789756207
# Left speed: 0.36618546187461265
# Right speed: 0.4
# small raod: 440.0
# Mode left line detected
# Target angle: 125.4
# steering angel: 7.379484197754962
# Left speed: 0.4
# Right speed: 0.29603944619706246
# small raod: 540.5
# Mode left line detected
# Target angle: 145.0
# steering angel: 10.2540110701162
# Left speed: 0.4
# Right speed: 0.27017478643513615
# small raod: 820.6666666666666
# Mode left line detected
# Target angle: 145.0
# steering angel: 3.524610445496819
# Left speed: 0.4
# Right speed: 0.36183310067443397
# small raod: 388.75
# Mode 2 lines detected
# steering angel: 0.3546683321282664
# Left speed: 0.4
# Right speed: 0.3957405776620562
# small raod: 569.0
# Mode right line detected
# Target angle: -130.7
# steering angel: -5.312299737754522
# Left speed: 0.3326169663146738
# Right speed: 0.4
# small raod: 614.8
# Mode right line detected
# Target angle: -153.8
# steering angel: -4.3708906651052075
# Left speed: 0.3513965058682301
# Right speed: 0.4
# small raod: 616.6666666666666
# Mode right line detected
# Target angle: -147.0
# steering angel: 11.120052217691693
# Left speed: 0.4
# Right speed: 0.24448271113233366
# small raod: 201.5
# Mode 2 lines detected
# steering angel: -11.016034423444385
# Left speed: 0.24452288592793942
# Right speed: 0.4
# small raod: 277.0
# steering angel: -11.016034423444385
# Left speed: 0.2694035009145229
# Right speed: 0.4
# small raod: 500.6666666666667
# Mode 2 lines detected
# steering angel: 2.418977263889035
# Left speed: 0.4
# Right speed: 0.3522610439832489
# small raod: 1767.5
# Mode right line detected
# Target angle: -126.2
# steering angel: -12.578138494221072
# Left speed: 0.23166896700601447
# Right speed: 0.4
# small raod: 1745.0
# Mode left line detected
# Target angle: 138.3
# steering angel: 30.0
# Left speed: 0.4
# Right speed: 0.0
# small raod: 1723.0
# Mode left line detected
# Target angle: 140.5
# steering angel: 9.603510708955056
# Left speed: 0.4
# Right speed: 0.3017037318285844
# small raod: 1022.0
# Mode 2 lines detected
# steering angel: 0.13392857142857142
# Left speed: 0.3951473794934546
# Right speed: 0.4
# small raod: 1929.3333333333333
# Mode left line detected
# Target angle: 113.8
# steering angel: 5.05202436038963
# Left speed: 0.4
# Right speed: 0.32810363417349153
# small raod: 624.5
# Mode left line detected
# Target angle: 175.5
# steering angel: 7.447354230704491
# Left speed: 0.4
# Right speed: 0.3015744946623295
# small raod: 378.0
# Mode 2 lines detected
# steering angel: 2.008928571428571
# Left speed: 0.4
# Right speed: 0.37544893749964475
# small raod: 1089.5
# Mode 2 lines detected
# steering angel: -1.3740992705945476
# Left speed: 0.38590645468290297
# Right speed: 0.4
# small raod: 1051.5
# Mode right line detected
# Target angle: -147.0
# steering angel: -5.016997280273287
# Left speed: 0.34149881654566905
# Right speed: 0.4
# small raod: 765.0
# Mode 2 lines detected
# steering angel: -3.187339491873822
# Left speed: 0.3696120477319631
# Right speed: 0.4
# small raod: 613.0
# Mode 2 lines detected
# steering angel: -1.8093657287035787
# Left speed: 0.3854178973144208
# Right speed: 0.4
# small raod: 391.6666666666667
# Mode left line detected
# Target angle: 125.4
# steering angel: 4.499467375421091
# Left speed: 0.4
# Right speed: 0.33244682849686996
# small raod: 793.0
# Mode left line detected
# Target angle: 133.4
# steering angel: 4.734703438512717
# Left speed: 0.4
# Right speed: 0.3364691329385532
# small raod: 660.5
# Mode left line detected
# Target angle: 131.2
# steering angel: 0.5406651610391293
# Left speed: 0.4
# Right speed: 0.3921129458625806
# small raod: 576.5
# Mode 2 lines detected
# steering angel: 0.9897943478245026
# Left speed: 0.4
# Right speed: 0.38097910933501855
# small raod: 386.0
# Mode 2 lines detected
# steering angel: -0.6364485794918957
# Left speed: 0.3969069301921977
# Right speed: 0.4
# small raod: 690.5
# Mode right line detected
# Target angle: -130.3
# steering angel: -4.107183329247029
# Left speed: 0.3526513951560166
# Right speed: 0.4
# small raod: 748.5
# Mode right line detected
# Target angle: -132.9
# steering angel: -2.556833649974159
# Left speed: 0.3770344365747397
# Right speed: 0.4
# small raod: 618.0
# Mode 2 lines detected
# steering angel: -1.6593052949465645
# Left speed: 0.38681400418663864
# Right speed: 0.4
# small raod: 393.0
# Mode 2 lines detected
# steering angel: 0.6020084325337465
# Left speed: 0.4
# Right speed: 0.384320964191299
# small raod: 353.75
# Mode 2 lines detected
# steering angel: 2.9024567571734687
# Left speed: 0.4
# Right speed: 0.3564046247840393
# small raod: 289.6
# Mode 2 lines detected
# steering angel: 3.2741460906101163
# Left speed: 0.4
# Right speed: 0.35389635158505595
# small raod: 584.5
# Mode 2 lines detected
# steering angel: 1.24604080549968
# Left speed: 0.4
# Right speed: 0.38099579898970504
# small raod: 619.0
# Mode right line detected
# Target angle: -126.2
# steering angel: -3.7819262131302764
# Left speed: 0.3545468634305799
# Right speed: 0.4
# small raod: 743.0
# Mode right line detected
# Target angle: -132.1
# steering angel: -3.5307756150063696
# Left speed: 0.363655674781584
# Right speed: 0.4
# small raod: 630.5
# Mode 2 lines detected
# steering angel: -1.9227964602479652
# Left speed: 0.38439566357373794
# Right speed: 0.4
# small raod: 572.0
# Mode 2 lines detected
# steering angel: -0.037354667356140264
# Left speed: 0.4
# Right speed: 0.3926336256205698
# small raod: 427.0
# Mode 2 lines detected
# steering angel: 2.0567250316765366
# Left speed: 0.4
# Right speed: 0.3672508669630712
# small raod: 341.75
# Mode 2 lines detected
# steering angel: 3.0235679887748184
# Left speed: 0.4
# Right speed: 0.3564659584773106
# small raod: 588.5
# Mode 2 lines detected
# steering angel: 1.587064519543511
# Left speed: 0.4
# Right speed: 0.3764644406534866
# small raod: 587.0
# Mode right line detected
# Target angle: -124.9
# steering angel: -3.288235901294833
# Left speed: 0.360482775980986
# Right speed: 0.4
# Stopping robot...

# %%
camera.stop()

# %%
robot.stop()

# %%
from logging import raiseExceptions
from cv2 import VideoCapture, imshow, rectangle, waitKey, destroyAllWindows, CAP_PROP_FRAME_WIDTH, CAP_PROP_FRAME_HEIGHT
from pyzbar.pyzbar import decode as decode_qr
import time

class QRCodeDetect:
    def __init__(self):
        """Initialize the camera"""
        self.camera = VideoCapture(0)
        self.camera.set(CAP_PROP_FRAME_WIDTH, 320)
        self.camera.set(CAP_PROP_FRAME_HEIGHT, 240)
        time.sleep(2)

        if not self.camera.isOpened():
            raise Exception("Could not open camera")

    def DetectQRCode(self, frame):
        """Detect and process QR Code in frame"""
        decoded_qrs = decode_qr(frame)
        imshow('QR Detection', frame)

        if decoded_qrs == None:
            print('decoded_qrs is None')
            raiseExceptions

        # Process detected QR code
        for qr_code in decoded_qrs:
            # Get the barcode's data and type
            data = qr_code.data.decode('utf-8')

            # Get QR code position and dimensions
            qr_rect = qr_code.rect
            qr_left = qr_rect.left
            qr_top = qr_rect.top
            qr_width = qr_rect.width
            qr_height = qr_rect.height

            # Calculate center coordinates
            qr_center_x = qr_left + (qr_width / 2)
            qr_center_y = qr_top + (qr_height / 2)

            # Calculate distance from frame center
            offset_x = qr_center_x - (frame.shape[1] / 2)
            offset_y = qr_center_y - (frame.shape[0] / 2)

            # Draw outline around detected QR code
            rectangle(frame,
                      (qr_left, qr_top),
                      (qr_left + qr_width, qr_top + qr_height),
                      (0, 255, 0),  # Green color
                      6)  # Line thickness

            imshow('QR Detection', frame)
            return data, offset_x, offset_y

    def run(self):
        """Continuously read QR codes"""
        while True:
            ret, frame = self.camera.read()
            if not ret:
                print("Failed to grab frame")
                continue

            try:
                data, offset_x, offset_y = self.DetectQRCode(frame)
                if data is not None:
                    print(f"Data: {data}")
                    print(f"X_offset: {offset_x:.1f}")
                    print(f"Y_offset: {offset_y:.1f}")

            except:
                pass

            if waitKey(1) & 0xFF == ord('q'):
                break

        self.cleanup()

    def cleanup(self):
        """Release camera and cleanup"""
        self.camera.release()
        destroyAllWindows()


def main():
    try:
        detector = QRCodeDetect()
        detector.run()

    except Exception as e:
        print(f"An error occurred: {str(e)}")


if __name__ == "__main__":
    main()
